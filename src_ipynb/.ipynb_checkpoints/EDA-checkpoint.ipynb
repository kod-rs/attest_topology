# %%
import pandas

data = pandas.read_csv('../estimator_data/WP 4/A_KPC_35/Loading/KPC_35_A_Bd.csv', header=[0, 1])

# %%
data[('season', 'spring')] = 0
data[('season', 'summer')] = 0
data[('season', 'autumn')] = 1
data[('season', 'winter')] = 0

data[('day', 'business')] = 1
data[('day', 'saturday')] = 0
data[('day', 'sunday')] = 0
data
# Out:
#            1                   2                   3                   4  \
#            P         Q         P         Q         P         Q         P
# 0   3.087995  0.077775  0.968075 -0.302022  3.070758 -0.432730  0.151568
# 1   3.163050  0.020874  0.924976 -0.311411  3.045989 -0.432152  0.104759
# 2   3.095979  0.047894  0.908362 -0.304276  2.961433 -0.424412  0.087289
# 3   3.109687  0.027368  0.895329 -0.318605  2.931798 -0.413958  0.096441
# 4   3.029582  0.030035  0.862517 -0.318950  2.846133 -0.430790  0.099186
# ..       ...       ...       ...       ...       ...       ...       ...
# 90       NaN       NaN  1.509819 -0.188568  4.104822 -0.426359  0.416756
# 91       NaN       NaN  1.536139 -0.144982  3.812678 -0.421073  0.347789
# 92       NaN       NaN  1.548984 -0.175973  3.751854 -0.430049  0.368760
# 93       NaN       NaN  1.521988 -0.183111  3.632589 -0.431427  0.278117
# 94       NaN       NaN  1.453423 -0.199973  3.483462 -0.438036  0.241008
#
# ...

# %%
from matplotlib import pyplot as plt

for bus in ['1', '2', '3', '4', '5', '6', '7']:
    plt.plot(data[bus, 'P'], label=bus)
plt.legend()
